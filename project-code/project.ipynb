# %%
import numpy as np
import pandas

# %%
training= pandas.read_csv('cs-training.csv', sep=',')

# %%
training
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1                 1                              0.766127
# 1                2                 0                              0.957151
# 2                3                 0                              0.658180
# 3                4                 0                              0.233810
# 4                5                 0                              0.907239
# 5                6                 0                              0.213179
# 6                7                 0                              0.305682
# 7                8                 0                              0.754464
# 8                9                 0                              0.116951
# 9               10                 0                              0.189169
# 10              11                 0                              0.644226
# ...

# %%
type(training)
# Out:
# pandas.core.frame.DataFrame

# %%
training.describe()
# Out:
# C:\Users\NhiYobie\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4274: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()  # an empty figure with no axes
training.plot()

# %%
training.iloc[:,1:3]

training.iloc[:,1].value_counts()
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %%
# %matplotlib inline

training.iloc[:,1].value_counts().plot(kind='bar')

# %%
training.iloc[:,2].plot()

# %%
plt.figure(2)  # an empty figure with no axes

# %%
training.iloc[:,2].plot(kind='hist')

# %%
plt.figure(3)  # an empty figure with no axes

# %%
plt.plot(training.iloc[:,1], training.iloc[:,2])

# %%
plt.figure(4)  # an empty figure with no axes

# %%
plt.figure(5)  # an empty figure with no axes

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.swarmplot(x="SeriousDlqin2yrs", y="RevolvingUtilizationOfUnsecuredLines", data=training)

# %%
plt.show()

# %%
# %matplotlib inline

training.iloc[:,3].plot()

# %%
training.value_counts('NaN')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-2ba39058cfe2> in <module>()
# ----> 1 training.value_counts('NaN')
#
# C:\Users\NhiYobie\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
training.loc[:, training.isna().any()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-40407dab0945> in <module>()
# ----> 1 training.loc[:, training.isna().any()]
#
# C:\Users\NhiYobie\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
training.isna().any()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e45f1cc7cc2e> in <module>()
# ----> 1 training.isna().any()
#
# C:\Users\NhiYobie\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
training.isnull().any()
# Out:
# Unnamed: 0                              False
# SeriousDlqin2yrs                        False
# RevolvingUtilizationOfUnsecuredLines    False
# age                                     False
# NumberOfTime30-59DaysPastDueNotWorse    False
# DebtRatio                               False
# MonthlyIncome                            True
# NumberOfOpenCreditLinesAndLoans         False
# NumberOfTimes90DaysLate                 False
# NumberRealEstateLoansOrLines            False
# NumberOfTime60-89DaysPastDueNotWorse    False
# NumberOfDependents                       True
# dtype: bool

# %%
training.isnull().sum()
# Out:
# Unnamed: 0                                  0
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %%
training['MonthlyIncome'].mean()
# Out:
# 6670.221237392844

# %%
training['NumberOfDependents'].mean()
# Out:
# 0.7572222678605657

# %%
training['MonthlyIncome'].fillna(training['MonthlyIncome'].mean())
# Out:
# 0          9120.000000
# 1          2600.000000
# 2          3042.000000
# 3          3300.000000
# 4         63588.000000
# 5          3500.000000
# 6          6670.221237
# 7          3500.000000
# 8          6670.221237
# 9         23684.000000
# 10         2500.000000
# 11         6501.000000
# 12        12454.000000
# 13        13700.000000
# 14            0.000000
# 15        11362.000000
# 16         6670.221237
# 17         8800.000000
# 18         3280.000000
# 19          333.000000
# 20        12300.000000
# 21         3000.000000
# 22         2500.000000
# 23         7916.000000
# 24         2416.000000
# 25         4676.000000
# 26         8333.000000
# 27         2500.000000
# 28         3400.000000
# 29         5500.000000
#               ...
# 149970    15500.000000
# 149971     5000.000000
# 149972     6945.000000
# 149973     5500.000000
# 149974     5000.000000
# 149975     6670.221237
# 149976     6670.221237
# 149977     6670.221237
# 149978     2500.000000
# ...

# %%
training['NumberOfDependents'].fillna(training['NumberOfDependents'].mean())
# Out:
# 0         2.000000
# 1         1.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
# 5         1.000000
# 6         0.000000
# 7         0.000000
# 8         0.757222
# 9         2.000000
# 10        0.000000
# 11        2.000000
# 12        2.000000
# 13        2.000000
# 14        0.000000
# 15        2.000000
# 16        0.000000
# 17        0.000000
# 18        2.000000
# 19        0.000000
# 20        0.000000
# 21        2.000000
# 22        0.000000
# 23        0.000000
# 24        0.000000
# 25        1.000000
# 26        0.000000
# 27        1.000000
# 28        0.000000
# 29        0.000000
#             ...
# 149970    2.000000
# 149971    0.000000
# 149972    1.000000
# 149973    1.000000
# 149974    0.000000
# 149975    0.000000
# 149976    0.000000
# 149977    0.000000
# 149978    0.000000
# 149979    0.000000
# 149980    0.000000
# 149981    4.000000
# 149982    3.000000
# 149983    0.000000
# 149984    0.000000
# 149985    0.000000
# ...

# %%
training.isnull().any()
# Out:
# Unnamed: 0                              False
# SeriousDlqin2yrs                        False
# RevolvingUtilizationOfUnsecuredLines    False
# age                                     False
# NumberOfTime30-59DaysPastDueNotWorse    False
# DebtRatio                               False
# MonthlyIncome                            True
# NumberOfOpenCreditLinesAndLoans         False
# NumberOfTimes90DaysLate                 False
# NumberRealEstateLoansOrLines            False
# NumberOfTime60-89DaysPastDueNotWorse    False
# NumberOfDependents                       True
# dtype: bool

# %%
training.isnull().sum()
# Out:
# Unnamed: 0                                  0
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %%
training['NumberOfDependents'] = training['NumberOfDependents'].fillna((training['NumberOfDependents'].mean()))

# %%
training.isnull().sum()
# Out:
# Unnamed: 0                                  0
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                          0
# dtype: int64

# %%
training['MonthlyIncome']= training['MonthlyIncome'].fillna(training['MonthlyIncome'].mean())

# %%
training.isnull().sum()
# Out:
# Unnamed: 0                              0
# SeriousDlqin2yrs                        0
# RevolvingUtilizationOfUnsecuredLines    0
# age                                     0
# NumberOfTime30-59DaysPastDueNotWorse    0
# DebtRatio                               0
# MonthlyIncome                           0
# NumberOfOpenCreditLinesAndLoans         0
# NumberOfTimes90DaysLate                 0
# NumberRealEstateLoansOrLines            0
# NumberOfTime60-89DaysPastDueNotWorse    0
# NumberOfDependents                      0
# dtype: int64

# %%
training.all(axis=None)
# Out:
# Unnamed: 0                               True
# SeriousDlqin2yrs                        False
# RevolvingUtilizationOfUnsecuredLines    False
# age                                     False
# NumberOfTime30-59DaysPastDueNotWorse    False
# DebtRatio                               False
# MonthlyIncome                           False
# NumberOfOpenCreditLinesAndLoans         False
# NumberOfTimes90DaysLate                 False
# NumberRealEstateLoansOrLines            False
# NumberOfTime60-89DaysPastDueNotWorse    False
# NumberOfDependents                      False
# dtype: bool

# %%
training.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
training.loc[training['NumberOfTime30-59DaysPastDueNotWorse'] == 98]
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 1733          1734                 1                                   1.0
# 2286          2287                 0                                   1.0
# 3884          3885                 0                                   1.0
# 4417          4418                 0                                   1.0
# 4705          4706                 0                                   1.0
# 5073          5074                 0                                   1.0
# 6280          6281                 1                                   1.0
# 7032          7033                 1                                   1.0
# 7117          7118                 1                                   1.0
# 7687          7688                 1                                   1.0
# 8173          8174                 1                                   1.0
# ...

# %%
corr= training.corr(method='pearson', min_periods=1)

corr[1:2]
# Out:
#                   Unnamed: 0  SeriousDlqin2yrs  \
# SeriousDlqin2yrs    0.002801               1.0
#
#                   RevolvingUtilizationOfUnsecuredLines       age  \
# SeriousDlqin2yrs                             -0.001802 -0.115386
#
#                   NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  \
# SeriousDlqin2yrs                              0.125587  -0.007602
#
#                   MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# SeriousDlqin2yrs      -0.018002                        -0.029669
#
#                   NumberOfTimes90DaysLate  NumberRealEstateLoansOrLines  \
# SeriousDlqin2yrs                 0.117175                     -0.007038
#
#                   NumberOfTime60-89DaysPastDueNotWorse  NumberOfDependents
# SeriousDlqin2yrs                              0.102261            0.045621

# %%
corr
# Out:
#                                       Unnamed: 0  SeriousDlqin2yrs  \
# Unnamed: 0                              1.000000          0.002801
# SeriousDlqin2yrs                        0.002801          1.000000
# RevolvingUtilizationOfUnsecuredLines    0.002372         -0.001802
# age                                     0.004403         -0.115386
# NumberOfTime30-59DaysPastDueNotWorse   -0.000571          0.125587
# DebtRatio                              -0.002906         -0.007602
# MonthlyIncome                           0.002356         -0.018002
# NumberOfOpenCreditLinesAndLoans         0.004586         -0.029669
# NumberOfTimes90DaysLate                -0.001104          0.117175
# NumberRealEstateLoansOrLines           -0.000666         -0.007038
# NumberOfTime60-89DaysPastDueNotWorse   -0.000777          0.102261
# NumberOfDependents                     -0.000055          0.045621
#
#                                       RevolvingUtilizationOfUnsecuredLines  \
# ...

# %%
import matplotlib.pyplot as plt


# %matplotlib inline
fig = plt.figure(figsize=(500, 500))
fig=corr.plot(kind='bar')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=2)
